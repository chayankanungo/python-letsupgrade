# %%
 
#ASSIGNMENT QUESTION 1
list=[0,1,2,10,4,1,0,56,2,0,1,3,0,56,0,4]
list2=[]
list.sort()
print(list)
count=0
while count<list.count(0):
  for i in list:
     if i == 0:
       list.remove(i)
       list.append(i)
       count+=1
print("The output required is",list)
# Out:
# [0, 0, 0, 0, 0, 1, 1, 1, 2, 2, 3, 4, 4, 10, 56, 56]
# The output required is [1, 1, 1, 2, 2, 3, 4, 4, 10, 56, 56, 0, 0, 0, 0, 0]

# %%
 
#ASSIGNMENT QUESTION 2 
list1=[10,20,40,60,70,80]
list2=[5,15,25,35,45,60]
i,j=0,0
list=[]
while i<len(list1) and j<len(list2):
  if list1[i]<list2[j]:
    list.append(list1[i])
    i+=1
  else:
    list.append(list2[j])
    j+=1
if i==len(list1):
  while j<len(list2):
    list.append(list2[j])
    j+=1
elif j==len(list2):
  while i<len(list1):
    list.append(list1[i])
    i+=1
print(list)
# Out:
# [5, 10, 15, 20, 25, 35, 40, 45, 60, 60, 70, 80]
