# %%
string="what we think we become; we are Python programmer "
sub=input("enter a substring")
i=string.find(sub)
if i==-1:
 print("substring no found ")
while i!=-1:
 print("{} is found at index:{}".format(sub,i))
 i=string.find(sub,i+len(sub),len(string))
# Out:
# enter a substringwe
# we is found at index:5
# we is found at index:14
# we is found at index:25

# %%
#islower()
x="chayan"
x.islower()
# Out:
# True

# %%
x="Chayan"
x.islower()
# Out:
# False

# %%
 #isupper()
x="Chayan"
x.isupper()
# Out:
# False

# %%
 x="CHAYAN"
x.isupper()
# Out:
# True
